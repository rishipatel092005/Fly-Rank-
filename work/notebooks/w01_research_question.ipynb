# %% [markdown]
# <a href="https://colab.research.google.com/github/rishipatel092005/Fly-Rank-/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rishipatel092005/Fly-Rank-/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose **Refresh / Content Opportunity Scoring** because it focuses on identifying which content pages should be reviewed first. This is a practical machine learning problem that helps prioritize pages that may benefit from updates instead of relying only on manual review. I chose this lane because I want to learn how machine learning can support better decision-making using real-world search data

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## My Lane
#
# I chose **Refresh / Content Opportunity Scoring** because it focuses on identifying which content pages should be reviewed first. This is a practical machine learning problem that can help prioritize pages needing updates instead of relying only on manual review. I chose this lane because I want to learn how machine learning can support better decision-making using real-world search data.

# %% [markdown]
# ## The Question
#
# Decision:
# Which content pages should be reviewed first?
#
# Action:
# The content or SEO team reviews and updates the highest-priority pages.
#
# Cost of a wrong recommendation:
# If the wrong pages are recommended, time and effort are wasted while important pages that need updates may be ignored.
#
# Why ML helps:
# Machine learning can analyze multiple signals together and rank pages more effectively than simple manual rules.
# """

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# First, let's make sure the data is available. It appears the data is stored in the associated GitHub repository. I'll clone the repository to access the data file.

# %% [markdown]
# Now, I will modify the next cell to load the CSV file from the cloned repository's directory.

# %%
import pandas as pd

df = pd.read_csv("Fly-Rank-/data/raw/content_refresh_anonymized.csv")

print("Total Rows:", len(df))
print("Total Columns:", len(df.columns))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 3))
# Out:
# Total Rows: 30000
# Total Columns: 44
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.511

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# False

# %% [markdown]
# ## Careful Words
#
# This project identifies patterns in the provided dataset and supports decision-making for prioritizing content review.
#
# The findings are based only on the available dataset and should be interpreted as observed trends rather than proof.
#
# This project does not predict Google's algorithm or guarantee that refreshing a page will improve its ranking.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
