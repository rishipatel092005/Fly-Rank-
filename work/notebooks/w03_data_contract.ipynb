# %% [markdown]
# <a href="https://colab.research.google.com/github/rishipatel092005/Fly-Rank-/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rishipatel092005/Fly-Rank-/blob/main/work/notebooks/w03_data_contract.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One row represents one content page for a specific month.
#
# The analysis will use a mid-panel month (for example, March 2026) to develop features and avoid using the final month for training.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Show dataset information
print("Rows:", len(df))
print("Columns:", len(df.columns))

# Display first five rows
df.head()
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ## Fields
#
# ### Features
# - search_volume
# - ctr
# - avg_position
# - engagement_rate
# - trend_direction
#
# ### Label
# - Refresh priority (ranking target)
#
# ### Context
# - content_type
# - main_intent
#
# ### Excluded
# - content_id (identifier only)
# - client_id (identifier only)
#
# The excluded fields are identifiers and do not provide useful predictive information for the model.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nMissing Values")
print(df.isnull().sum())

print("\nFirst 5 Rows")
display(df.head())
# Out:
# Rows: 30000
# Columns: 44
#
# Missing Values
# content_id                    0
# client_id                     0
# search_volume              2468
# competition                2468
# competition_level          2610
# cpc                        2468
# content_type                  0
# main_intent                2374
# word_count                 7699
# char_count                 7699
# provider_used             21438
# model_used                 5733
# impressions_90d               0
# clicks_90d                    0
# pageviews_90d                 0
# sessions_90d                  0
# users_90d                     0
# engaged_sessions_90d          0
# ai_sessions_90d               0
# scroll_events_90d             0
# days_with_impressions         0
# days_with_sessions            0
# impressions_last_30d          0
# clicks_last_30d               0
# sessions_last_30d             0
# impressions_prev_30d          0
# clicks_prev_30d               0
# sessions_prev_30d             0
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## Data Limits
#
# This dataset contains observed search performance data.
#
# It cannot prove that refreshing a page will improve rankings.
#
# The results should be interpreted as decision support rather than causal evidence.
#
# Some fields contain missing values and may require preprocessing before modeling.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
